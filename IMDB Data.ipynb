# %%
import pandas as pd
import numpy as np

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
basics.replace({'\\N':np.nan})
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9733629  tt9916848  tvEpisode              Episode #3.17
# 9733630  tt9916850  tvEpisode              Episode #3.19
# 9733631  tt9916852  tvEpisode              Episode #3.20
# 9733632  tt9916856      short                   The Wind
# 9733633  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# ...

# %%
basics.dropna(subset=['runtimeMinutes'], inplace=True)
basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            11
# dtype: int64

# %%
basics.dropna(subset=['genres'], inplace=True)
basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres             0
# dtype: int64

# %%
basics['titleType'].value_counts()
movie_filter = basics['titleType'] == 'movie'
basics.loc[movie_filter, :].head()
# Out:
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 144  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 498  tt0000502     movie                       Bohemios
# 570  tt0000574     movie    The Story of the Kelly Gang
# 587  tt0000591     movie               The Prodigal Son
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry       0      1894      \N             45
# 144  The Corbett-Fitzsimmons Fight       0      1897      \N            100
# 498                       Bohemios       0      1905      \N            100
# 570    The Story of the Kelly Gang       0      1906      \N             70
# 587              L'enfant prodigue       0      1907      \N             90
#
#                          genres
# 8                       Romance
# 144      Documentary,News,Sport
# 498                          \N
# 570  Action,Adventure,Biography
# ...

# %%
Filter = basics['startYear'] >= '2000'
Filter2 = basics['startYear'] < '2022'

# %%
basics = basics.loc[movie_filter]
basics = basics.loc[Filter & Filter2]
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272008 entries, 11636 to 9733584
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          272008 non-null  object
#  1   titleType       272008 non-null  object
#  2   primaryTitle    272008 non-null  object
#  3   originalTitle   272008 non-null  object
#  4   isAdult         272008 non-null  object
#  5   startYear       272008 non-null  object
#  6   endYear         272008 non-null  object
#  7   runtimeMinutes  272008 non-null  object
#  8   genres          272008 non-null  object
# dtypes: object(9)
# memory usage: 20.8+ MB
#           tconst titleType                                       primaryTitle  \
# 11636  tt0011801     movie                                   Tötet nicht mehr
# 13082  tt0013274     movie                        Istoriya grazhdanskoy voyny
# ...

# %%
basics = basics[(basics['genres'].notna())]

# %%
documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~documentary]

# %%
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 11636  tt0011801     movie                                   Tötet nicht mehr
# 15178  tt0015414     movie                             La tierra de los toros
# 34803  tt0035423     movie                                     Kate & Leopold
# 61116  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67669  tt0069049     movie                         The Other Side of the Wind
#
#                                    originalTitle isAdult startYear endYear  \
# 11636                           Tötet nicht mehr       0      2019      \N
# 15178                     La tierra de los toros       0      2000      \N
# 34803                             Kate & Leopold       0      2001      \N
# 61116  El tango del viudo y su espejo deformante       0      2020      \N
# 67669                 The Other Side of the Wind       0      2018      \N
#
#       runtimeMinutes                  genres
# ...

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1966
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1804
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2604

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1295778 entries, 0 to 1295777
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1295778 non-null  object
#  1   averageRating  1295778 non-null  float64
#  2   numVotes       1295778 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 29.7+ MB

# %%
ratings = ratings.replace({'\\N':np.nan})

# %%
akas.info()
akas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35431302 entries, 0 to 35431301
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ GB
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# ...

# %%
akas = akas.replace({'\\N':np.nan})

# %%
us_filter = akas['region'] == 'US'
akas = akas[(us_filter)]

# %%
keep = basics['tconst'].isin(akas['titleId'])

# %%
basics = basics[keep]
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34803  tt0035423     movie                                     Kate & Leopold
# 61116  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67669  tt0069049     movie                         The Other Side of the Wind
# 86801  tt0088751     movie                                  The Naked Monster
# 93938  tt0096056     movie                               Crime and Punishment
#
#                                    originalTitle isAdult startYear endYear  \
# 34803                             Kate & Leopold       0      2001      \N
# 61116  El tango del viudo y su espejo deformante       0      2020      \N
# 67669                 The Other Side of the Wind       0      2018      \N
# 86801                          The Naked Monster       0      2005      \N
# 93938                       Crime and Punishment       0      2002      \N
#
#       runtimeMinutes                  genres
# ...

# %%
include = ratings['tconst'].isin(akas['titleId'])

# %%
include = ratings['tconst'].isin(akas['titleId'])
ratings = ratings[include]

# %%
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
